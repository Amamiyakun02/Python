# %%
import datetime
import numpy as np

# %%
date = datetime.datetime.now()

print(date.year)
print(date.strftime("%A"))
print(date.strftime("%B"))

if date.strftime("%B") == "February":
    print("Hellow")
# Out:
# 2023
# Thursday
# February
# Hellow

# %%
datetim = datetime.datetime(2023, 2,15)
print(datetim)

centu = date.strftime('%C') 

if int(centu) == 20:
    print("This is 20 Century")
else:
    print("is not 20 century")

print(date.strftime('%f'))

num = [np.random.randint(30,799) for i in range(10)]

print(max(num))

triple = [i**3 for i in range(100)]
print(triple)
# Out:
# 2023-02-15 00:00:00
# This is 20 Century
# 035510
# 700
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000, 1331, 1728, 2197, 2744, 3375, 4096, 4913, 5832, 6859, 8000, 9261, 10648, 12167, 13824, 15625, 17576, 19683, 21952, 24389, 27000, 29791, 32768, 35937, 39304, 42875, 46656, 50653, 54872, 59319, 64000, 68921, 74088, 79507, 85184, 91125, 97336, 103823, 110592, 117649, 125000, 132651, 140608, 148877, 157464, 166375, 175616, 185193, 195112, 205379, 216000, 226981, 238328, 250047, 262144, 274625, 287496, 300763, 314432, 328509, 343000, 357911, 373248, 389017, 405224, 421875, 438976, 456533, 474552, 493039, 512000, 531441, 551368, 571787, 592704, 614125, 636056, 658503, 681472, 704969, 729000, 753571, 778688, 804357, 830584, 857375, 884736, 912673, 941192, 970299]

# %%
print(num)
print(np.argmax(num))
rand_num = np.array([np.random.randint(1,200) for x in range(60)])
rand_num = rand_num.reshape([3,4,5])
print(rand_num)
print(rand_num.argmax())
for x in rand_num:
    print(x)
# Out:
# [590, 649, 669, 111, 700, 83, 285, 328, 266, 462]
# 4
# [[[ 99 153 135  70  12]
#   [139 153 174 123  64]
#   [172 178  91 151  38]
#   [128  26 126 188  67]]
#
#  [[173  71 166 121 176]
#   [  6 110 121  72  62]
#   [110  28 146 125 113]
#   [110 106 134 187 183]]
#
#  [[131  13  14 127  69]
#   [ 68 170 184  15 136]
#   [163 143  84  28 196]
#   [194 179 175 186 198]]]
# 59
# [[ 99 153 135  70  12]
#  [139 153 174 123  64]
#  [172 178  91 151  38]
#  [128  26 126 188  67]]
# [[173  71 166 121 176]
#  [  6 110 121  72  62]
#  [110  28 146 125 113]
#  [110 106 134 187 183]]
# [[131  13  14 127  69]
#  [ 68 170 184  15 136]
#  [163 143  84  28 196]
#  [194 179 175 186 198]]

# %%
import math

# %%
PI = math.pi
print(PI)
exp = math.exp(1)
print(exp)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import matplotlib.pyplot as plt 

bilx = np.array([i for i in range(-50,51)])
bily = pow(bilx,2)
ax = plt.subplot()
plt.subplot(1,2,1)
plt.plot(bilx,bily)

bily = 2 * bilx
plt.subplot(1,2,2)
plt.plot(bilx,bily)
plt.plot(0,100)
ax.axhline(y = 0,color='k')

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7532\984351864.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
